# %% [markdown]
# ## Import Data from EVSE

# %%
import requests
import folium
import gmaps
import gmaps.datasets
import collections
collections.Iterable = collections.abc.Iterable
import pandas as pd
from pandas import json_normalize

url = "https://data.geo.admin.ch/ch.bfe.ladestellen-elektromobilitaet/data/ch.bfe.ladestellen-elektromobilitaet.json"

response = requests.get(url)

response_json = response.json()

df = json_normalize(response_json["EVSEData"])

df
# Out:
#                                        EVSEDataRecord          OperatorID  \
# 0   [{'AccessibilityLocation': 'OnStreet', 'Addres...      CH*SWISSCHARGE
# 1   [{'Accessibility': 'Paying publicly accessible...              CH*CCC
# 2   [{'Accessibility': 'Free publicly accessible',...              CH*ECU
# 3   [{'EvseID': 'CHFASE4150401', 'Accessibility': ...          CH*FASTNED
# 4   [{'deltaType': 'insert', 'lastUpdate': '2023-0...              CH*REP
# 5   [{'Accessibility': 'Free publicly accessible',...               CHEVP
# 6   [{'Accessibility': 'Restricted access', 'Acces...              CH*AIL
# 7   [{'Accessibility': 'Paying publicly accessible...   CH*ENMOBILECHARGE
# 8   [{'Accessibility': 'Paying publicly accessible...   CH*EVAEMOBILITAET
# 9   [{'Accessibility': 'Paying publicly accessible...        CH*EWACHARGE
# 10  [{'Accessibility': 'Restricted access', 'Acces...     CH*MOBILECHARGE
# 11  [{'Accessibility': 'Paying publicly accessible...  CH*MOBIMOEMOBILITY
# 12  [{'Accessibility': 'Free publicly accessible',...     CH*PACEMOBILITY
# 13  [{'Accessibility': 'Paying publicly accessible...       CH*PARKCHARGE
# 14  [{'Accessibility': 'Paying publicly accessible...          CH*SCHARGE
# 15  [{'Accessibility': 'Paying publicly accessible...              CH*TAE
# 16  [{'EvseID': 'CH*AVI*E123*0001', 'HotlinePhoneN...             CH*AVIA
# 17  [{'EvseID': 'CH*DIE*E123*0001', 'HotlinePhoneN...              CH*DIE
# 18  [{'EvseID': 'CH*EBS*E123*0004', 'HotlinePhoneN...              CH*EBS
# 19  [{'EvseID': 'CH*EWD*E123*0033', 'HotlinePhoneN...              CH*EWD
# 20  [{'EvseID': 'CH*EWO*E123*0001', 'HotlinePhoneN...              CH*EWO
# 21  [{'EvseID': 'CH*HER*E123*0001', 'HotlinePhoneN...              CH*HER
# 22  [{'EvseID': 'CH*ION*E202401', 'HotlinePhoneNum...              CH*ION
# 23  [{'EvseID': 'CH*LID*E123*0001', 'HotlinePhoneN...             CH*LIDL
# 24  [{'EvseID': 'CH*MIG*E123*0001', 'HotlinePhoneN...              CH*MIG
# 25  [{'EvseID': 'CH*TES*E123*0001', 'HotlinePhoneN...              CH*TES
# 26  [{'EvseID': 'CH*SCH*EJXJX517362SCH', 'Charging...              CH*SCH
# 27  [{'Accessibility': 'Restricted access', 'Addre...              CH*CPI
# 28  [{'Accessibility': 'Free publicly accessible',...              CH*SHE
#
#                       OperatorName
# 0                      Swisscharge
# 1                             Move
# 2                           eCarUp
# 3                          Fastned
# 4                      PLUG N ROLL
# 5                           evpass
# 6                              AIL
# 7                   ENMOBILECHARGE
# 8                   EVAEMOBILITAET
# 9                        EWACHARGE
# 10                    MOBILECHARGE
# 11                 MOBIMOEMOBILITY
# 12                    PACEMOBILITY
# 13                      PARKCHARGE
# 14                         SCHARGE
# 15                             TAE
# 16                            AVIA
# 17                  Stadt Dietikon
# 18                  ebs Energie AG
# 19  EWD Elektrizitätswerk Davos AG
# 20      Elektrizitätswerk Obwalden
# 21    Elektrizitätswerk Herrliberg
# 22                          IONITY
# 23                    Lidl Schweiz
# 24            Migrol Fast Charging
# 25                           Tesla
# 26                      Saascharge
# 27                     Chargepoint
# 28                  Shell Recharge

# %%
print(df.iloc[0])

df_data_record = pd.json_normalize(data=response_json["EVSEData"], record_path='EVSEDataRecord')
df_data_record
# Out:
# EVSEDataRecord    [{'AccessibilityLocation': 'OnStreet', 'Addres...
# OperatorID                                           CH*SWISSCHARGE
# OperatorName                                            Swisscharge
# Name: 0, dtype: object
#       AccessibilityLocation         AuthenticationModes  \
# 0                  OnStreet  [NFC RFID Classic, REMOTE]
# 1                  OnStreet  [NFC RFID Classic, REMOTE]
# 2                  OnStreet  [NFC RFID Classic, REMOTE]
# 3                  OnStreet  [NFC RFID Classic, REMOTE]
# 4                  OnStreet  [NFC RFID Classic, REMOTE]
# ...                     ...                         ...
# 13612                  None                          []
# 13613                  None                          []
# 13614                  None                          []
# 13615                  None                          []
# 13616                  None                          []
#
#       CalibrationLawDataAvailability  \
# 0                      Not Available
# 1                      Not Available
# 2                      Not Available
# 3                      Not Available
# 4                      Not Available
# ...                              ...
# 13612                  Not Available
# 13613                  Not Available
# 13614                  Not Available
# 13615                  Not Available
# 13616                  Not Available
#
#                                ChargingFacilities  \
# 0             [{'power': 100, 'powertype': 'DC'}]
# 1              [{'power': 50, 'powertype': 'DC'}]
# 2      [{'power': 22, 'powertype': 'AC_3_PHASE'}]
# 3              [{'power': 60, 'powertype': 'DC'}]
# 4             [{'power': 150, 'powertype': 'DC'}]
# ...                                           ...
# 13612         [{'power': 300, 'powertype': 'DC'}]
# 13613         [{'power': 300, 'powertype': 'DC'}]
# 13614         [{'power': 300, 'powertype': 'DC'}]
# 13615         [{'power': 300, 'powertype': 'DC'}]
# 13616         [{'power': 300, 'powertype': 'DC'}]
#
#                                     ChargingStationNames DynamicInfoAvailable  \
# 0      [{'lang': 'de', 'value': 'GOFAST Schwyz-Seewen...                 true
# 1      [{'lang': 'de', 'value': 'GOFAST Schwyz-Seewen...                 true
# 2      [{'lang': 'de', 'value': 'GOFAST Schwyz-Seewen...                 true
# 3      [{'lang': 'de', 'value': 'GOFAST Schwyz-Seewen...                 true
# 4      [{'lang': 'de', 'value': 'GOFAST Spreitenbach ...                 true
# ...                                                  ...                  ...
# 13612  [{'lang': 'en', 'value': 'Shell Rosenberg Wint...                 true
# 13613  [{'lang': 'en', 'value': 'Shell Fohlenweide Br...                 true
# 13614           [{'lang': 'en', 'value': 'Shell Staad'}]                 true
# 13615  [{'lang': 'en', 'value': 'Shell Fohlenweide Br...                 true
# 13616  [{'lang': 'en', 'value': 'Shell Fohlenweide Br...                 true
#
#       HotlinePhoneNumber   HubOperatorID  IsHubjectCompatible  IsOpen24Hours  \
# 0           +41713881150  CH*SWISSCHARGE                 True           True
# 1           +41713881150  CH*SWISSCHARGE                 True           True
# 2           +41713881150  CH*SWISSCHARGE                 True           True
# 3           +41713881150  CH*SWISSCHARGE                 True           True
# 4           +41713881150  CH*SWISSCHARGE                 True           True
# ...                  ...             ...                  ...            ...
# 13612       +41800769444            None                False           True
# 13613       +41800769444            None                False           True
# 13614       +41800769444            None                False           True
# 13615       +41800769444            None                False           True
# 13616       +41800769444            None                False           True
#
#        ...           Address.Street Address.Floor  Address.Region  \
# 0      ...       Bahnhofstrasse 158          None            None
# 1      ...       Bahnhofstrasse 158          None            None
# 2      ...       Bahnhofstrasse 158          None            None
# 3      ...       Bahnhofstrasse 158          None            None
# 4      ...         Wigartestrasse 4          None            None
# ...    ...                      ...           ...             ...
# 13612  ...  Schaffhauserstrasse 154          None            None
# 13613  ...         Wohlerstrasse 18          None            None
# 13614  ...          Hauptstrasse 30          None            None
# 13615  ...         Wohlerstrasse 18          None            None
# 13616  ...         Wohlerstrasse 18          None            None
#
#       Address.ParkingSpot Address.ParkingFacility GeoCoordinates.Google  \
# 0                    None                    None    47.028107 8.631626
# 1                    None                    None    47.028107 8.631626
# 2                    None                    None    47.028107 8.631626
# 3                    None                    None    47.028107 8.631626
# 4                    None                    None    47.418408 8.373644
# ...                   ...                     ...                   ...
# 13612                None                    None  47.5190554 8.7189126
# 13613                None                    None  47.3555097 8.3257443
# 13614                None                    None  47.4799829 9.5314007
# 13615                None                    None  47.3555097 8.3257443
# 13616                None                    None  47.3555097 8.3257443
#
#       GeoChargingPointEntrance.Google ChargingStationNames.value  \
# 0                           None None                        NaN
# 1                           None None                        NaN
# 2                           None None                        NaN
# 3                           None None                        NaN
# 4                           None None                        NaN
# ...                               ...                        ...
# 13612                       None None                        NaN
# 13613                       None None                        NaN
# 13614                       None None                        NaN
# 13615                       None None                        NaN
# 13616                       None None                        NaN
#
#       ChargingStationNames.lang SubOperatorName
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
# ...                         ...             ...
# 13612                       NaN
# 13613                       NaN
# 13614                       NaN
# 13615                       NaN
# 13616                       NaN
#
# [13617 rows x 46 columns]

# %%
lat_lon = {
    "lat": [],
    "lon": []
}   
df_lat_lon = pd.DataFrame(lat_lon)

for i in range(0, len(df_data_record)):
    lat_lon_list = df_data_record.iloc[i]['GeoCoordinates.Google'].split()
    df_lat_lon.loc[len(df_lat_lon)] = lat_lon_list

convert_dict = {
    'lat': float,
    'lon': float
}

df_lat_lon = df_lat_lon.astype(convert_dict)

print(df_lat_lon.dtypes)
df_lat_lon
# Out:
# lat    float64
# lon    float64
# dtype: object
#              lat       lon
# 0      47.028107  8.631626
# 1      47.028107  8.631626
# 2      47.028107  8.631626
# 3      47.028107  8.631626
# 4      47.418408  8.373644
# ...          ...       ...
# 13612  47.519055  8.718913
# 13613  47.355510  8.325744
# 13614  47.479983  9.531401
# 13615  47.355510  8.325744
# 13616  47.355510  8.325744
#
# [13617 rows x 2 columns]

# %% [markdown]
# #### Todo: Check if it works with gmaps. Else find another solution

# %%
gmaps.configure(api_key='API key')

charger_layer = gmaps.symbol_layer(df_lat_lon, fill_color='green', stroke_color='green')
switzerland_coordinates = (46.8182, 8.2275)
fig = gmaps.figure(center=switzerland_coordinates, zoom_level=7)
fig.add_layer(charger_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
